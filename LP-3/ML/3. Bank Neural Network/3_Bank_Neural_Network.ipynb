# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
# pip install tensorflow ignore if already installed

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %%
dataset = pd.read_csv('Churn_Modelling.csv', index_col = 'RowNumber')

# %%
dataset.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
#
#            EstimatedSalary  Exited
# RowNumber
# 1                101348.88       1
# 2                112542.58       0
# 3                113931.57       1
# 4                 93826.63       0
# 5                 79084.10       0

# %%
# Features and target
X = dataset.iloc[:, 2:12]
X  # drop CustomerId and Surname
# Out:
#            CreditScore Geography  Gender  Age  Tenure    Balance  \
# RowNumber
# 1                  619    France  Female   42       2       0.00
# 2                  608     Spain  Female   41       1   83807.86
# 3                  502    France  Female   42       8  159660.80
# 4                  699    France  Female   39       1       0.00
# 5                  850     Spain  Female   43       2  125510.82
# ...                ...       ...     ...  ...     ...        ...
# 9996               771    France    Male   39       5       0.00
# 9997               516    France    Male   35      10   57369.61
# 9998               709    France  Female   36       7       0.00
# 9999               772   Germany    Male   42       3   75075.31
# 10000              792    France  Female   28       4  130142.79
#
#            NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# RowNumber
# 1                      1          1               1        101348.88
# 2                      1          0               1        112542.58
# 3                      3          1               0        113931.57
# 4                      2          0               0         93826.63
# 5                      1          1               1         79084.10
# ...                  ...        ...             ...              ...
# 9996                   2          1               0         96270.64
# 9997                   1          1               1        101699.77
# 9998                   1          0               1         42085.58
# 9999                   2          1               0         92888.52
# 10000                  1          1               0         38190.78
#
# [10000 rows x 10 columns]

# %%
# Features and target
Y = dataset.iloc[:, 12].values  # Churn column
Y
# Out:
# array([1, 0, 1, ..., 1, 1, 0])

# %% [markdown]
# We are treating countries with ordinal values(0 < 1 < 2) but they are incomparable.
# To solve this we can use one hot encoding.
# We will perform some standardization

# %%
# Pipeline: One-hot encode categorical and scale
pipeline = Pipeline([
    ('preprocess', ColumnTransformer(
        transformers=[
            ('gender', OneHotEncoder(drop='first'), ['Gender']),
            ('geo', OneHotEncoder(drop='first'), ['Geography'])
        ],
        remainder='passthrough'
    )),
    ('scaler', StandardScaler())
])

# %%
#Standardize the features
X = pipeline.fit_transform(X)

# %%
#Spilt the data
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
# Build ANN
classifier = Sequential()
classifier.add(Dense(6, activation='relu', input_shape=(X_train.shape[1],)))
classifier.add(Dropout(0.1))
classifier.add(Dense(6, activation='relu'))
classifier.add(Dropout(0.1))
classifier.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile ANN
classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train ANN
history = classifier.fit(X_train, y_train, batch_size=32, epochs=100, validation_split=0.1, verbose=2)
# Out:
# Epoch 1/100
# 225/225 - 2s - 9ms/step - accuracy: 0.7961 - loss: 0.5369 - val_accuracy: 0.7950 - val_loss: 0.4721
# Epoch 2/100
# 225/225 - 0s - 2ms/step - accuracy: 0.7961 - loss: 0.4891 - val_accuracy: 0.7950 - val_loss: 0.4478
# Epoch 3/100
# 225/225 - 0s - 2ms/step - accuracy: 0.7961 - loss: 0.4713 - val_accuracy: 0.7950 - val_loss: 0.4334
# Epoch 4/100
# 225/225 - 0s - 2ms/step - accuracy: 0.7961 - loss: 0.4552 - val_accuracy: 0.7950 - val_loss: 0.4234
# Epoch 5/100
# 225/225 - 0s - 2ms/step - accuracy: 0.7961 - loss: 0.4498 - val_accuracy: 0.7950 - val_loss: 0.4162
# Epoch 6/100
# 225/225 - 0s - 2ms/step - accuracy: 0.7961 - loss: 0.4408 - val_accuracy: 0.7950 - val_loss: 0.4099
# Epoch 7/100
# 225/225 - 0s - 2ms/step - accuracy: 0.7961 - loss: 0.4334 - val_accuracy: 0.7950 - val_loss: 0.4056
# Epoch 8/100
# 225/225 - 1s - 2ms/step - accuracy: 0.7961 - loss: 0.4308 - val_accuracy: 0.7950 - val_loss: 0.4025
# Epoch 9/100
# 225/225 - 0s - 2ms/step - accuracy: 0.7961 - loss: 0.4301 - val_accuracy: 0.7950 - val_loss: 0.3991
# Epoch 10/100
# 225/225 - 0s - 2ms/step - accuracy: 0.7961 - loss: 0.4245 - val_accuracy: 0.7950 - val_loss: 0.3958
# Epoch 11/100
# 225/225 - 0s - 2ms/step - accuracy: 0.7961 - loss: 0.4228 - val_accuracy: 0.7950 - val_loss: 0.3929
# Epoch 12/100
# 225/225 - 0s - 2ms/step - accuracy: 0.7961 - loss: 0.4158 - val_accuracy: 0.7950 - val_loss: 0.3893
# Epoch 13/100
# 225/225 - 0s - 2ms/step - accuracy: 0.7961 - loss: 0.4136 - val_accuracy: 0.7950 - val_loss: 0.3867
# Epoch 14/100
# 225/225 - 0s - 2ms/step - accuracy: 0.7961 - loss: 0.4158 - val_accuracy: 0.7950 - val_loss: 0.3840
# Epoch 15/100
# 225/225 - 1s - 3ms/step - accuracy: 0.7962 - loss: 0.4149 - val_accuracy: 0.7950 - val_loss: 0.3817
# Epoch 16/100
# 225/225 - 1s - 3ms/step - accuracy: 0.8100 - loss: 0.4145 - val_accuracy: 0.8350 - val_loss: 0.3801
# Epoch 17/100
# 225/225 - 1s - 6ms/step - accuracy: 0.8251 - loss: 0.4110 - val_accuracy: 0.8400 - val_loss: 0.3780
# Epoch 18/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8244 - loss: 0.4124 - val_accuracy: 0.8462 - val_loss: 0.3764
# Epoch 19/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8264 - loss: 0.4112 - val_accuracy: 0.8425 - val_loss: 0.3743
# Epoch 20/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8335 - loss: 0.4058 - val_accuracy: 0.8475 - val_loss: 0.3711
# Epoch 21/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8315 - loss: 0.4051 - val_accuracy: 0.8487 - val_loss: 0.3702
# Epoch 22/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8306 - loss: 0.4045 - val_accuracy: 0.8500 - val_loss: 0.3688
# Epoch 23/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8322 - loss: 0.4054 - val_accuracy: 0.8475 - val_loss: 0.3672
# Epoch 24/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8343 - loss: 0.4056 - val_accuracy: 0.8500 - val_loss: 0.3669
# Epoch 25/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8342 - loss: 0.4000 - val_accuracy: 0.8512 - val_loss: 0.3653
# Epoch 26/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8376 - loss: 0.3978 - val_accuracy: 0.8487 - val_loss: 0.3640
# Epoch 27/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8358 - loss: 0.3949 - val_accuracy: 0.8487 - val_loss: 0.3637
# Epoch 28/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8383 - loss: 0.3969 - val_accuracy: 0.8462 - val_loss: 0.3626
# Epoch 29/100
# 225/225 - 1s - 3ms/step - accuracy: 0.8358 - loss: 0.3981 - val_accuracy: 0.8512 - val_loss: 0.3621
# Epoch 30/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8374 - loss: 0.3992 - val_accuracy: 0.8512 - val_loss: 0.3612
# Epoch 31/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8389 - loss: 0.3971 - val_accuracy: 0.8500 - val_loss: 0.3600
# Epoch 32/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8399 - loss: 0.3952 - val_accuracy: 0.8512 - val_loss: 0.3599
# Epoch 33/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8389 - loss: 0.3894 - val_accuracy: 0.8512 - val_loss: 0.3594
# Epoch 34/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8397 - loss: 0.3926 - val_accuracy: 0.8512 - val_loss: 0.3585
# Epoch 35/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8410 - loss: 0.3924 - val_accuracy: 0.8587 - val_loss: 0.3580
# Epoch 36/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8382 - loss: 0.3891 - val_accuracy: 0.8550 - val_loss: 0.3585
# Epoch 37/100
# 225/225 - 1s - 2ms/step - accuracy: 0.8404 - loss: 0.3889 - val_accuracy: 0.8562 - val_loss: 0.3575
# Epoch 38/100
# 225/225 - 1s - 3ms/step - accuracy: 0.8415 - loss: 0.3918 - val_accuracy: 0.8575 - val_loss: 0.3559
# Epoch 39/100
# 225/225 - 1s - 3ms/step - accuracy: 0.8440 - loss: 0.3879 - val_accuracy: 0.8612 - val_loss: 0.3537
# Epoch 40/100
# 225/225 - 1s - 6ms/step - accuracy: 0.8424 - loss: 0.3888 - val_accuracy: 0.8600 - val_loss: 0.3530
# Epoch 41/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8401 - loss: 0.3841 - val_accuracy: 0.8612 - val_loss: 0.3506
# Epoch 42/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8396 - loss: 0.3878 - val_accuracy: 0.8650 - val_loss: 0.3516
# Epoch 43/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8399 - loss: 0.3859 - val_accuracy: 0.8650 - val_loss: 0.3495
# Epoch 44/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8449 - loss: 0.3812 - val_accuracy: 0.8625 - val_loss: 0.3475
# Epoch 45/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8429 - loss: 0.3861 - val_accuracy: 0.8625 - val_loss: 0.3476
# Epoch 46/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8456 - loss: 0.3847 - val_accuracy: 0.8662 - val_loss: 0.3464
# Epoch 47/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8408 - loss: 0.3850 - val_accuracy: 0.8662 - val_loss: 0.3458
# Epoch 48/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8468 - loss: 0.3808 - val_accuracy: 0.8650 - val_loss: 0.3451
# Epoch 49/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8476 - loss: 0.3790 - val_accuracy: 0.8637 - val_loss: 0.3441
# Epoch 50/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8468 - loss: 0.3802 - val_accuracy: 0.8625 - val_loss: 0.3424
# Epoch 51/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8486 - loss: 0.3776 - val_accuracy: 0.8712 - val_loss: 0.3425
# Epoch 52/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8428 - loss: 0.3844 - val_accuracy: 0.8675 - val_loss: 0.3428
# Epoch 53/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8429 - loss: 0.3815 - val_accuracy: 0.8662 - val_loss: 0.3411
# Epoch 54/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8478 - loss: 0.3774 - val_accuracy: 0.8687 - val_loss: 0.3395
# Epoch 55/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8450 - loss: 0.3820 - val_accuracy: 0.8675 - val_loss: 0.3380
# Epoch 56/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8464 - loss: 0.3788 - val_accuracy: 0.8687 - val_loss: 0.3361
# Epoch 57/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8453 - loss: 0.3720 - val_accuracy: 0.8700 - val_loss: 0.3334
# Epoch 58/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8451 - loss: 0.3749 - val_accuracy: 0.8675 - val_loss: 0.3331
# Epoch 59/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8485 - loss: 0.3700 - val_accuracy: 0.8675 - val_loss: 0.3318
# Epoch 60/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8457 - loss: 0.3718 - val_accuracy: 0.8662 - val_loss: 0.3309
# Epoch 61/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8458 - loss: 0.3719 - val_accuracy: 0.8675 - val_loss: 0.3304
# Epoch 62/100
# 225/225 - 1s - 3ms/step - accuracy: 0.8507 - loss: 0.3696 - val_accuracy: 0.8650 - val_loss: 0.3287
# Epoch 63/100
# 225/225 - 1s - 3ms/step - accuracy: 0.8456 - loss: 0.3754 - val_accuracy: 0.8662 - val_loss: 0.3288
# Epoch 64/100
# 225/225 - 1s - 5ms/step - accuracy: 0.8464 - loss: 0.3736 - val_accuracy: 0.8650 - val_loss: 0.3292
# Epoch 65/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8483 - loss: 0.3687 - val_accuracy: 0.8687 - val_loss: 0.3278
# Epoch 66/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8478 - loss: 0.3716 - val_accuracy: 0.8700 - val_loss: 0.3282
# Epoch 67/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8486 - loss: 0.3693 - val_accuracy: 0.8612 - val_loss: 0.3289
# Epoch 68/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8486 - loss: 0.3669 - val_accuracy: 0.8625 - val_loss: 0.3281
# Epoch 69/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8458 - loss: 0.3718 - val_accuracy: 0.8637 - val_loss: 0.3287
# Epoch 70/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8487 - loss: 0.3697 - val_accuracy: 0.8625 - val_loss: 0.3284
# Epoch 71/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8501 - loss: 0.3678 - val_accuracy: 0.8662 - val_loss: 0.3283
# Epoch 72/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8497 - loss: 0.3677 - val_accuracy: 0.8637 - val_loss: 0.3288
# Epoch 73/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8501 - loss: 0.3688 - val_accuracy: 0.8637 - val_loss: 0.3283
# Epoch 74/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8469 - loss: 0.3707 - val_accuracy: 0.8637 - val_loss: 0.3283
# Epoch 75/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8454 - loss: 0.3697 - val_accuracy: 0.8662 - val_loss: 0.3286
# Epoch 76/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8501 - loss: 0.3625 - val_accuracy: 0.8650 - val_loss: 0.3268
# Epoch 77/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8479 - loss: 0.3689 - val_accuracy: 0.8650 - val_loss: 0.3289
# Epoch 78/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8499 - loss: 0.3688 - val_accuracy: 0.8650 - val_loss: 0.3277
# Epoch 79/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8469 - loss: 0.3650 - val_accuracy: 0.8662 - val_loss: 0.3275
# Epoch 80/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8496 - loss: 0.3677 - val_accuracy: 0.8612 - val_loss: 0.3284
# Epoch 81/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8474 - loss: 0.3687 - val_accuracy: 0.8662 - val_loss: 0.3274
# Epoch 82/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8511 - loss: 0.3640 - val_accuracy: 0.8625 - val_loss: 0.3272
# Epoch 83/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8475 - loss: 0.3694 - val_accuracy: 0.8625 - val_loss: 0.3273
# Epoch 84/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8425 - loss: 0.3692 - val_accuracy: 0.8587 - val_loss: 0.3272
# Epoch 85/100
# 225/225 - 1s - 2ms/step - accuracy: 0.8454 - loss: 0.3731 - val_accuracy: 0.8600 - val_loss: 0.3264
# Epoch 86/100
# 225/225 - 1s - 3ms/step - accuracy: 0.8518 - loss: 0.3647 - val_accuracy: 0.8637 - val_loss: 0.3252
# Epoch 87/100
# 225/225 - 1s - 6ms/step - accuracy: 0.8482 - loss: 0.3659 - val_accuracy: 0.8625 - val_loss: 0.3257
# Epoch 88/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8490 - loss: 0.3666 - val_accuracy: 0.8637 - val_loss: 0.3258
# Epoch 89/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8439 - loss: 0.3690 - val_accuracy: 0.8612 - val_loss: 0.3258
# Epoch 90/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8439 - loss: 0.3691 - val_accuracy: 0.8650 - val_loss: 0.3270
# Epoch 91/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8490 - loss: 0.3653 - val_accuracy: 0.8625 - val_loss: 0.3260
# Epoch 92/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8469 - loss: 0.3673 - val_accuracy: 0.8625 - val_loss: 0.3264
# Epoch 93/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8447 - loss: 0.3653 - val_accuracy: 0.8587 - val_loss: 0.3262
# Epoch 94/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8483 - loss: 0.3672 - val_accuracy: 0.8625 - val_loss: 0.3260
# Epoch 95/100
# 225/225 - 1s - 5ms/step - accuracy: 0.8447 - loss: 0.3684 - val_accuracy: 0.8637 - val_loss: 0.3268
# Epoch 96/100
# 225/225 - 2s - 7ms/step - accuracy: 0.8465 - loss: 0.3652 - val_accuracy: 0.8637 - val_loss: 0.3257
# Epoch 97/100
# 225/225 - 2s - 8ms/step - accuracy: 0.8447 - loss: 0.3635 - val_accuracy: 0.8612 - val_loss: 0.3260
# Epoch 98/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8431 - loss: 0.3639 - val_accuracy: 0.8650 - val_loss: 0.3249
# Epoch 99/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8414 - loss: 0.3668 - val_accuracy: 0.8625 - val_loss: 0.3244
# Epoch 100/100
# 225/225 - 0s - 2ms/step - accuracy: 0.8447 - loss: 0.3662 - val_accuracy: 0.8612 - val_loss: 0.3255

# %%
# Predict
y_pred = (classifier.predict(X_test) > 0.5).astype(int)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
y_pred = classifier.predict(X_test)
print(y_pred[:5])
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# [[0.29576513]
#  [0.27789894]
#  [0.17470004]
#  [0.0738398 ]
#  [0.13504124]]

# %%
#Let us use confusion matrix with cutoff value as 0.5
y_pred = (y_pred > 0.5).astype(int)
print(y_pred[:5])
# Out:
# [[0]
#  [0]
#  [0]
#  [0]
#  [0]]

# %%
#Making the Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[1527   68]
#  [ 215  190]]

# %%
#Accuracy of our NN
print(((cm[0][0] + cm[1][1])* 100) / len(y_test), '% of data was classified correctly')
# Out:
# 85.85 % of data was classified correctly
